# %%
import pandas as pd

# %%
import sqlite3

# %%
con = sqlite3.connect("C:/Users/SSAFY/ssafy10/myPJT/FINAL_PJT/FinancePal/final_pjt_back/db.sqlite3")

# %%
query = 'SELECT * FROM accounts_user'

# %%
df = pd.read_sql(query, con)
con.close()
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\SSAFY\ssafy10\myPJT\추천 알고리즘\Untitled.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/ssafy10/myPJT/%EC%B6%94%EC%B2%9C%20%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/Untitled.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_sql(query, con)
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/ssafy10/myPJT/%EC%B6%94%EC%B2%9C%20%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/Untitled.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> con.close()
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/ssafy10/myPJT/%EC%B6%94%EC%B2%9C%20%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/Untitled.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:635, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633 with pandasSQL_builder(con) as pandas_sql:
#     634     if isinstance(pandas_sql, SQLiteDatabase):
# --> 635         return pandas_sql.read_query(
#     636             sql,
#     637             index_col=index_col,
#     638             params=params,
#     639             coerce_float=coerce_float,
#     640             parse_dates=parse_dates,
#     641             chunksize=chunksize,
#     642             dtype_backend=dtype_backend,  # type: ignore[arg-type]
#     643             dtype=dtype,
#     644         )
#     646     try:
#     647         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:2266, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2255 def read_query(
#    2256     self,
#    2257     sql,
#    (...)
#    2264     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265 ) -> DataFrame | Iterator[DataFrame]:
# -> 2266     cursor = self.execute(sql, params)
#    2267     columns = [col_desc[0] for col_desc in cursor.description]
#    2269     if chunksize is not None:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:2200, in SQLiteDatabase.execute(self, sql, params)
#    2198     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2199 args = [] if params is None else [params]
# -> 2200 cur = self.con.cursor()
#    2201 try:
#    2202     cur.execute(sql, *args)
#
# ProgrammingError: Cannot operate on a closed database.

# %%
import datetime

# %%
user = df[df['username'] == 'rcFp2vNap']
user
# Out:
#    id password last_login  is_superuser   username first_name last_name email  \
# 0   1     1234       None             0  rcFp2vNap          허        유준
#
#    is_staff  is_active                 date_joined nickname   address  \
# 0         0          1  2023-11-20 02:54:21.510000    허유준82  대전광역시 중구
#
#    birth_date  gender     salary   balance
# 0  1968-05-10       0  293000000  16200000

# %%
user_birth_date = user['birth_date']
user_birth_date
# Out:
# 0    1968-05-10
# Name: birth_date, dtype: object

# %%
def calc_age(birthdate):
    today = datetime.datetime.today()
    birthdate = datetime.datetime.strptime(birthdate, '%Y-%m-%d')
    age = today.year-birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))
    return age

# %%
df['age'] = df['birth_date'].apply(calc_age)
user_age = df[df['username'] == 'rcFp2vNap']['age'].values[0]
user_salary = df[df['username'] == 'rcFp2vNap']['salary'].values[0]
user_age_balance = df[df['username'] == 'rcFp2vNap']['balance'].values[0]
df['age_diff'] = abs(df['age'] - user_age)
selected_columns = ['username', 'salary', 'balance', 'age_diff']
result_df = df.loc[:, selected_columns]
result_df.sort_values(by=['age_diff', 'salary', 'balance'])
# Out:
#                 username      salary   balance  age_diff
# 2391   H6pghSaBaO0tZsviO    12000000    700000         0
# 6859         EhzKCSFUuLf    53000000  90900000         0
# 8481        cxdTvVrB0zQG    81000000  95600000         0
# 7469     UdGMvr0MlTpLr8G   128000000  45600000         0
# 4897        jy1rDxRdIHkP   128000000  98200000         0
# ...                  ...         ...       ...       ...
# 6608        UxdoaON68cUT  1472000000  39300000        38
# 4761           JSfXBnYss  1475000000  22800000        38
# 9498  0FAZnVnhYUwy9Am0t6  1481000000  55900000        38
# 68           F3CRonxlrey  1484000000  27000000        38
# 376    OWR5TTPs5ODmmYWAP  1484000000  90400000        38
#
# [10000 rows x 4 columns]

# %%
con = sqlite3.connect("C:/Users/SSAFY/ssafy10/myPJT/FINAL_PJT/FinancePal/final_pjt_back/db.sqlite3")
query1 = 'SELECT * FROM accounts_user_deposit_products'
df1 = pd.read_sql(query1, con)
con.close()
print(df1)
# Out:
#           id  user_id            deposit_id
# 0          1        1      10-003-1225-0001
# 1          2        1     10511008001166004
# 2          3        2               WR0001B
# 3          4        2                     4
# 4          5        3  01013000110000000001
# ...      ...      ...                   ...
# 13243  13244     6211          010300100335
# 13244  13245     6212           01211310127
# 13245  13246     6213              21001115
# 13246  13247     6213     10511008001278000
# 13247  13248     6213        01030500560002
#
# [13248 rows x 3 columns]

# %%
merged_df = pd.merge(df, df1, on='user_id')
merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\SSAFY\ssafy10\myPJT\추천 알고리즘\Untitled.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/ssafy10/myPJT/%EC%B6%94%EC%B2%9C%20%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/Untitled.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> merged_df = pd.merge(df, df1, on='user_id')
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/ssafy10/myPJT/%EC%B6%94%EC%B2%9C%20%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/Untitled.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> merged_df
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:737, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     730 self._cross = cross_col
#     732 # note this function has side effects
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
# --> 737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
#     741 self._maybe_coerce_merge_keys()
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:1221, in _MergeOperation._get_merge_keys(self)
#    1217 if lk is not None:
#    1218     # Then we're either Hashable or a wrong-length arraylike,
#    1219     #  the latter of which will raise
#    1220     lk = cast(Hashable, lk)
# -> 1221     left_keys.append(left._get_label_or_level_values(lk))
#    1222     join_names.append(lk)
#    1223 else:
#    1224     # work-around for merge_asof(left_index=True)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:1778, in NDFrame._get_label_or_level_values(self, key, axis)
#    1776     values = self.axes[axis].get_level_values(key)._values
#    1777 else:
# -> 1778     raise KeyError(key)
#    1780 # Check for duplicates
#    1781 if values.ndim > 1:
#
# KeyError: 'user_id'

# %%
display(df1)
display(df)
# Out:
#           id  user_id            deposit_id
# 0          1        1      10-003-1225-0001
# 1          2        1     10511008001166004
# 2          3        2               WR0001B
# 3          4        2                     4
# 4          5        3  01013000110000000001
# ...      ...      ...                   ...
# 13243  13244     6211          010300100335
# 13244  13245     6212           01211310127
# 13245  13246     6213              21001115
# 13246  13247     6213     10511008001278000
# 13247  13248     6213        01030500560002
#
# [13248 rows x 3 columns]
#          id password last_login  is_superuser          username first_name  \
# 0         1     1234       None             0         rcFp2vNap          허
# 1         2     1234       None             0         9iRYGap7v          조
# 2         3     1234       None             0    fAzdKbsox05xOa          문
# 3         4     1234       None             0  KuDwOmYoTsz7wjDf          손
# 4         5     1234       None             0       b997HUENnNt          하
# ...     ...      ...        ...           ...               ...        ...
# 9995   9996     1234       None             0    FCAhjXHGPRlY86          고
# 9996   9997     1234       None             0  fgyr71oKW0zx3Ge9          홍
# 9997   9998     1234       None             0   5PpAe0S0DkyBd6M          강
# 9998   9999     1234       None             0     VerDSvFxZGMy5          문
# 9999  10000     1234       None             0          QNSJIPEe          송
#
#      last_name email  is_staff  is_active                 date_joined  \
# 0           유준               0          1  2023-11-20 02:54:21.510000
# 1           하준               0          1  2023-11-20 02:54:21.510000
# 2           지란               0          1  2023-11-20 02:54:21.510000
# 3           우진               0          1  2023-11-20 02:54:21.510000
# 4           건범               0          1  2023-11-20 02:54:21.510000
# ...        ...   ...       ...        ...                         ...
# 9995        운영               0          1  2023-11-20 02:54:25.056000
# 9996        금수               0          1  2023-11-20 02:54:25.056000
# 9997        현빈               0          1  2023-11-20 02:54:25.056000
# 9998        하호               0          1  2023-11-20 02:54:25.056000
# 9999        도영               0          1  2023-11-20 02:54:25.056000
#
#      nickname     address  birth_date  gender      salary   balance  age  \
# 0       허유준82    대전광역시 중구  1968-05-10       0   293000000  16200000   55
# 1       조하준55   대전광역시 유성구  2000-07-22       1   170000000  89500000   23
# 2       문지란43    부산광역시 남구  1964-04-28       0  1495000000   6000000   59
# 3       손우진14     용인시 기흥구  1967-07-14       1   795000000  64600000   56
# 4       하건범70   대전광역시 대덕구  1931-07-10       0   302000000  23500000   92
# ...       ...         ...         ...     ...         ...       ...  ...
# 9995     고운영6   인천광역시 연수구  1955-01-04       1   847000000  30200000   68
# 9996    홍금수14  서울특별시 동대문구  1930-01-09       0   224000000  18800000   93
# 9997    강현빈22     용인시 기흥구  2001-09-11       0    24000000  77600000   22
# 9998    문하호93    광주광역시 서구  1964-01-17       1  1233000000  22600000   59
# 9999    송도영12   서울특별시 광진구  1946-11-22       1    22000000  81800000   76
#
#       age_diff
# 0            0
# 1           32
# 2            4
# 3            1
# 4           37
# ...        ...
# 9995        13
# 9996        38
# 9997        33
# 9998         4
# 9999        21
#
# [10000 rows x 19 columns]

# %%
df_join = pd.merge(df, df1, left_on='id', right_on='user_id', how='inner')[['age', 'salary', 'balance', 'deposit_id']]

# %%
df_join
# Out:
#        age      salary   balance            deposit_id
# 0       55   293000000  16200000      10-003-1225-0001
# 1       55   293000000  16200000     10511008001166004
# 2       23   170000000  89500000               WR0001B
# 3       23   170000000  89500000                     4
